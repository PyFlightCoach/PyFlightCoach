# %%
from flightdata import Flight

from flightanalysis import Section, FlightLine

flight = Flight.from_csv("~/Desktop/logs/00000002.csv")
sec = Section.from_flight(flight, FlightLine.from_covariance(flight)).subset(191,237)
# Out:
# /home/tom/source/PyFlightCoach/geometry/geometry/points.py:103: RuntimeWarning:
#
# invalid value encountered in true_divide

# %%
import plotly.graph_objects as go
from plotly.subplots import make_subplots
fig = make_subplots(specs=[[{"secondary_y": True}]])

fig.add_trace(go.Scatter(x=sec.data.index, y=sec.data.brvr))
fig.add_trace(go.Scatter(x=sec.data.index, y=sec.data.brvp))
fig.add_trace(go.Scatter(x=sec.data.index, y=sec.data.brvy))
fig.add_trace(go.Scatter(x=sec.data.index, y=sec.data.bvx), secondary_y=True)

# %%
lroll = sec.data.brvr[192:197].mean()
rroll = sec.data.brvr[198:202].mean()

vlroll = sec.data.brvr[216.5:219].mean()
vrroll = sec.data.brvr[220:223].mean()

# %%
lroll, rroll, vlroll, vrroll
# Out:
# (-2.710412264845374,
#  2.7737278079317456,
#  -2.108259552192401,
#  2.2867105307232602)
