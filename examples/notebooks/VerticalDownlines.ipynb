# %% [markdown]
# # Downline Braking Investigation

# %%
from flightdata import Flight, Fields, CIDTypes
from geometry import Point, Coord
from math import pi
import numpy as np
import pandas as pd 
import plotly.graph_objects as go

def plot2d(datax, datay, colour='black', width=1, fig=None, name=None):
    if not fig:
        fig=go.Figure()
    fig.add_trace(go.Scatter(x=datax, y=datay, name=name, line=dict(color=colour, width=width)))
    fig.update_layout(width = 800, height = 500, margin=dict(l=20, r=20, t=20, b=20),)
    fig.update_yaxes(scaleanchor = "x",scaleratio = 1)
    return fig

def plot3d(datax, datay, dataz, colour='black',fig=None, width=1):
    if not fig:
        fig=go.Figure()
    fig.add_trace(go.Scatter3d(x=datax, y=datay, z=dataz, line=dict(color=colour, width=width),
        mode = 'lines'))
    fig.update_layout(width = 800, height = 500, margin=dict(l=20, r=20, t=20, b=20))
    fig.update_yaxes(scaleanchor = "x",scaleratio = 1)
    return fig

def rotate_data(bin, angle):
    # get a vector pointing in the desired x axis by rotating the default x axis vector by the angle requested.
    box_normal_vector = Point(1, 0, 0).rotate(Point(0,0,angle).to_rotation_matrix())

    #create a new Coord based on the origin (unchanged), the z axis (up), and the new x axis vector. 
    box_cid = Coord.from_zx(Point(0, 0, 0), Point(0, 0, -1), box_normal_vector)

    def point_to_box(x, y, z):
        box_point = Point(x, y, z).rotate(box_cid.rotation_matrix)
        return box_point.x, box_point.y, box_point.z

    def euler_to_box(x, y, z):
        seupoint = Point(x, y - pi, - z - angle)
        return seupoint.x, seupoint.y, seupoint.z

    transforms = {i: lambda *args: args  for i in range(0, 7)}
    transforms[CIDTypes.CARTESIAN] = point_to_box
    transforms[CIDTypes.EULER] = euler_to_box
    transforms[CIDTypes.ZONLY] = lambda *args: tuple(-arg for arg in args) 
    transforms[CIDTypes.XY]: lambda *args: point_to_box(*args, z=0) 
    
    return bin.transform(transforms)



bin=Flight.from_log('./braking/00000134.BIN')
flight = rotate_data(bin, -126*pi/180)
# Out:
#  0x11 at 10864418
# bad header 0x11 0x90 at 10864419
# bad header 0x90 0x89 at 10864420
# bad header 0x89 0x10 at 10864421
# bad header 0x10 0x00 at 10864422
# bad header 0x00 0x00 at 10864423
# bad header 0x00 0x00 at 10864424
# bad header 0x00 0x00 at 10864425
# bad header 0x00 0x18 at 10864426
# bad header 0x18 0x00 at 10864427
# bad header 0x00 0x05 at 10864428
# bad header 0x05 0x00 at 10864429
# bad header 0x00 0xe6 at 10864430
# bad header 0xe6 0xff at 10864431
# bad header 0xff 0xf7 at 10864432
# bad header 0xf7 0xff at 10864433
# bad header 0xff 0x00 at 10864434
# bad header 0x00 0x00 at 10864435
# bad header 0x00 0x04 at 10864436
# bad header 0x04 0x00 at 10864437
# bad header 0x00 0x00 at 10864438
# bad header 0x00 0x00 at 10864439
# bad header 0x00 0x00 at 10864440
# bad header 0x00 0x00 at 10864441
# bad header 0x00 0x00 at 10864442
# bad header 0x00 0x00 at 10864443
# bad header 0x00 0x37 at 10864444
# bad header 0x37 0xfe at 10864445
# bad header 0xfe 0x00 at 10864446
# bad header 0x00 0x00 at 10864447
# bad header 0x00 0xa3 at 10864448
# bad header 0xa3 0x15 at 10864673
# bad header 0x15 0x59 at 10864674
# bad header 0x59 0x11 at 10864675
# bad header 0x11 0x10 at 10864676
# bad header 0x10 0x89 at 10864677
# bad header 0x89 0x10 at 10864678
# bad header 0x10 0x00 at 10864679
# bad header 0x00 0x00 at 10864680
# bad header 0x00 0x00 at 10864681
# bad header 0x00 0x00 at 10864682
# bad header 0x00 0x05 at 10864683
# bad header 0x05 0x00 at 10864684
# bad header 0x00 0x01 at 10864685
# bad header 0x01 0x00 at 10864686
# bad header 0x00 0x01 at 10864687
# bad header 0x01 0x80 at 10864688
# bad header 0x80 0x04 at 10864689
# bad header 0x04 0x00 at 10864690
# bad header 0x00 0x00 at 10864691
# bad header 0x00 0x00 at 10864692
# bad header 0x00 0x00 at 10864693
# bad header 0x00 0x00 at 10864694
# bad header 0x00 0x80 at 10864695
# bad header 0x80 0x3f at 10864696
# bad header 0x3f 0x00 at 10864697
# bad header 0x00 0x05 at 10864698
# bad header 0x05 0x00 at 10864699
# bad header 0x00 0x00 at 10864700
# bad header 0x00 0x10 at 10864701
# bad header 0x10 0x3f at 10864702
# bad header 0x3f 0xa3 at 10864703
# bad header 0xa3 0x00 at 10864704
# bad header 0x00 0x00 at 10864705
# bad header 0x00 0x00 at 10864706
# bad header 0x00 0xa3 at 10864707
# bad header 0xa3 0x85 at 10864708
# bad header 0x85 0x60 at 10864709
# bad header 0x60 0x11 at 10864710
# bad header 0x11 0x90 at 10864711
# bad header 0x90 0x89 at 10864712
# bad header 0x89 0x10 at 10864713
# bad header 0x10 0x00 at 10864714
# bad header 0x00 0x04 at 10864715
# bad header 0x04 0x00 at 10864716
# bad header 0x00 0x00 at 10864717
# bad header 0x00 0xea at 10864718
# bad header 0xea 0xf5 at 10864719
# bad header 0xf5 0x68 at 10864720
# bad header 0x68 0xb7 at 10864721
# bad header 0xb7 0x67 at 10864722
# bad header 0x67 0xc6 at 10864723
# bad header 0xc6 0x20 at 10864724
# bad header 0x20 0x3e at 10864725
# bad header 0x3e 0xa9 at 10864726
# bad header 0xa9 0xbb at 10864727
# bad header 0xbb 0x77 at 10864728
# bad header 0x77 0xbe at 10864729
# bad header 0xbe 0x26 at 10864730
# bad header 0x26 0x35 at 10864731
# bad header 0x35 0xa4 at 10864732
# bad header 0xa4 0xbe at 10864733
# bad header 0xbe 0xa3 at 10864734
# unknown msg type 0x6c (108) at 10864811
# Skipped 31 bad bytes in log at offset 10864418, type=(83, 17, 144) (prev=90)
# Skipped 62 bad bytes in log at offset 10864673, type=(163, 21, 89) (prev=88)
# Skipped 97 bad bytes in log at offset 10864811, type=(163, 149, 108) (prev=199)
# Skipped 60 bad bytes in log at offset 10864947, type=(171, 149, 136) (prev=135)
# Skipped 34 bad bytes in log at offset 10865182, type=(163, 148, 186) (prev=185)
# Skipped 37 bad bytes in log at offset 10865253, type=(149, 139, 228) (prev=173)
# Skipped 27 bad bytes in log at offset 10866205, type=(171, 149, 95) (prev=85)
# Skipped 23 bad bytes in log at offset 10866438, type=(237, 171, 30) (prev=140)
# Skipped 31 bad bytes in log at offset 10866745, type=(61, 255, 139) (prev=5)
# Skipped 78 bad bytes in log at offset 10867042, type=(161, 149, 200) (prev=166)
# Skipped 55 bad bytes in log at offset 10867198, type=(225, 149, 64) (prev=204)
# Skipped 33 bad bytes in log at offset 10867288, type=(161, 149, 66) (prev=65)
# Skipped 82 bad bytes in log at offset 10867396, type=(162, 149, 78) (prev=68)
# Skipped 62 bad bytes in log at offset 10867546, type=(163, 149, 104) (prev=71)
# Skipped 106 bad bytes in log at offset 10867699, type=(83, 65, 236) (prev=90)
# Skipped 89 bad bytes in log at offset 10867832, type=(163, 181, 95) (prev=95)
# Skipped 7 bad bytes in log at offset 10868009, type=(215, 106, 190) (prev=91)
# Skipped 45 bad bytes in log at offset 10868110, type=(227, 212, 141) (prev=223)
# Skipped 36 bad bytes in log at offset 10868697, type=(131, 149, 165) (prev=186)
# Skipped 66 bad bytes in log at offset 10868824, type=(35, 149, 167) (prev=211)
# Skipped 94 bad bytes in log at offset 10868968, type=(163, 145, 204) (prev=202)
# Skipped 35 bad bytes in log at offset 10869130, type=(163, 133, 67) (prev=66)
# Skipped 90 bad bytes in log at offset 10869232, type=(163, 21, 69) (prev=78)
# Skipped 35 bad bytes in log at offset 10869355, type=(163, 181, 73) (prev=71)
# Skipped 40 bad bytes in log at offset 10869574, type=(163, 145, 85) (prev=84)
# Skipped 55 bad bytes in log at offset 10869641, type=(163, 148, 86) (prev=95)
# Skipped 61 bad bytes in log at offset 10869764, type=(148, 81, 142) (prev=82)
# Skipped 31 bad bytes in log at offset 10869870, type=(131, 149, 199) (prev=141)
# Skipped 28 bad bytes in log at offset 10870048, type=(4, 0, 0) (prev=131)
# Skipped 22 bad bytes in log at offset 10870132, type=(162, 149, 5) (prev=206)
# Skipped 11 bad bytes in log at offset 10870174, type=(73, 77, 69) (prev=145)
# Skipped 22 bad bytes in log at offset 10870247, type=(42, 97, 175) (prev=197)
# Skipped 172 bad bytes in log at offset 10870494, type=(163, 157, 201) (prev=200)
# Skipped 68 bad bytes in log at offset 10870701, type=(35, 151, 66) (prev=65)
# Skipped 55 bad bytes in log at offset 10870836, type=(163, 213, 69) (prev=78)
# Skipped 82 bad bytes in log at offset 10871218, type=(167, 133, 95) (prev=85)
# Skipped 33 bad bytes in log at offset 10871334, type=(171, 149, 88) (prev=87)
# Skipped 31 bad bytes in log at offset 10871474, type=(243, 149, 231) (prev=141)
# Skipped 49 bad bytes in log at offset 10871553, type=(171, 149, 17) (prev=0)
# Skipped 49 bad bytes in log at offset 10871740, type=(93, 140, 16) (prev=202)
# Skipped 39 bad bytes in log at offset 10872014, type=(163, 213, 201) (prev=200)
# Skipped 94 bad bytes in log at offset 10872092, type=(163, 133, 220) (prev=202)
# Skipped 117 bad bytes in log at offset 10872329, type=(131, 149, 78) (prev=68)
# Skipped 62 bad bytes in log at offset 10872479, type=(227, 149, 72) (prev=71)
# Skipped 55 bad bytes in log at offset 10872635, type=(39, 133, 67) (prev=225)
# Skipped 34 bad bytes in log at offset 10872690, type=(163, 149, 18) (prev=225)
# Skipped 6 bad bytes in log at offset 10872975, type=(0, 0, 141) (prev=80)
# Skipped 35 bad bytes in log at offset 10872981, type=(163, 149, 121) (prev=80)
# Skipped 17 bad bytes in log at offset 10873071, type=(238, 39, 224) (prev=64)
# Skipped 48 bad bytes in log at offset 10873119, type=(163, 21, 238) (prev=198)
# Skipped 127 bad bytes in log at offset 10873167, type=(163, 149, 17) (prev=198)
# Skipped 109 bad bytes in log at offset 10873294, type=(163, 149, 27) (prev=198)
# Skipped 29 bad bytes in log at offset 10873531, type=(0, 0, 4) (prev=191)
# Skipped 103 bad bytes in log at offset 10873670, type=(163, 133, 138) (prev=133)
# Skipped 8 bad bytes in log at offset 10873822, type=(16, 0, 95) (prev=244)
# Skipped 68 bad bytes in log at offset 10912810, type=(163, 213, 66) (prev=65)
# Skipped 55 bad bytes in log at offset 10912945, type=(163, 21, 69) (prev=78)
# Skipped 28 bad bytes in log at offset 10913040, type=(155, 80, 0) (prev=68)
# Skipped 68 bad bytes in log at offset 10913219, type=(163, 181, 19) (prev=82)
# Skipped 45 bad bytes in log at offset 10913538, type=(163, 149, 13) (prev=96)
# Skipped 29 bad bytes in log at offset 10913633, type=(163, 145, 0) (prev=236)
# Skipped 39 bad bytes in log at offset 10913750, type=(163, 148, 136) (prev=135)
# Skipped 175 bad bytes in log at offset 10913810, type=(163, 157, 206) (prev=11)
# Skipped 19 bad bytes in log at offset 10914093, type=(163, 151, 211) (prev=139)
# Skipped 31 bad bytes in log at offset 10914134, type=(60, 74, 242) (prev=5)
# Skipped 27 bad bytes in log at offset 10914218, type=(163, 21, 39) (prev=138)
# Skipped 27 bad bytes in log at offset 10914599, type=(171, 149, 78) (prev=68)
# Skipped 15 bad bytes in log at offset 10914666, type=(67, 197, 172) (prev=68)
# Skipped 151 bad bytes in log at offset 10914749, type=(171, 149, 74) (prev=71)
# Skipped 35 bad bytes in log at offset 10914933, type=(163, 213, 84) (prev=83)
# Skipped 55 bad bytes in log at offset 10915035, type=(163, 149, 118) (prev=95)
# Skipped 47 bad bytes in log at offset 10915145, type=(203, 255, 0) (prev=86)
# Skipped 76 bad bytes in log at offset 10915219, type=(163, 21, 133) (prev=96)
# Skipped 177 bad bytes in log at offset 10915314, type=(227, 149, 0) (prev=236)
# Skipped 53 bad bytes in log at offset 10915579, type=(163, 145, 138) (prev=133)
# Skipped 30 bad bytes in log at offset 10915682, type=(162, 133, 212) (prev=130)
# Skipped 80 bad bytes in log at offset 10915798, type=(131, 21, 138) (prev=133)
# Skipped 129 bad bytes in log at offset 10915995, type=(167, 149, 204) (prev=202)
# Skipped 82 bad bytes in log at offset 10916232, type=(171, 149, 78) (prev=68)
# Skipped 8 bad bytes in log at offset 10916341, type=(1, 0, 0) (prev=78)
# Skipped 55 bad bytes in log at offset 10916444, type=(163, 149, 17) (prev=79)
# Skipped 48 bad bytes in log at offset 10916675, type=(128, 64, 0) (prev=87)
# Skipped 33 bad bytes in log at offset 10916757, type=(171, 149, 88) (prev=87)
# Skipped 26 bad bytes in log at offset 10916826, type=(149, 64, 115) (prev=73)
# Skipped 23 bad bytes in log at offset 10916874, type=(245, 171, 30) (prev=140)
# Skipped 19 bad bytes in log at offset 10916928, type=(161, 181, 236) (prev=199)
# Skipped 39 bad bytes in log at offset 10917025, type=(163, 157, 135) (prev=1)
# Skipped 162 bad bytes in log at offset 10917103, type=(161, 149, 11) (prev=8)
# Skipped 53 bad bytes in log at offset 10917318, type=(227, 149, 138) (prev=133)
# Skipped 34 bad bytes in log at offset 10917405, type=(161, 149, 186) (prev=185)
# Skipped 18 bad bytes in log at offset 10917514, type=(149, 211, 103) (prev=203)
# Skipped 65 bad bytes in log at offset 10917572, type=(162, 66, 114) (prev=232)
# Skipped 8 bad bytes in log at offset 10917707, type=(0, 0, 0) (prev=196)
# Skipped 41 bad bytes in log at offset 10917797, type=(1, 0, 32) (prev=97)
# Skipped 67 bad bytes in log at offset 10917873, type=(167, 149, 68) (prev=67)
# Skipped 35 bad bytes in log at offset 10917995, type=(227, 213, 70) (prev=69)
# Skipped 67 bad bytes in log at offset 10918180, type=(227, 149, 83) (prev=81)
# Skipped 35 bad bytes in log at offset 10918247, type=(163, 149, 21) (prev=81)
# Skipped 67 bad bytes in log at offset 10918404, type=(162, 149, 87) (prev=86)
# Skipped 122 bad bytes in log at offset 10918506, type=(163, 148, 96) (prev=89)
# Skipped 49 bad bytes in log at offset 10918657, type=(162, 133, 1) (prev=0)
# Skipped 22 bad bytes in log at offset 10918840, type=(163, 133, 5) (prev=206)
# Skipped 3 bad bytes in log at offset 10918912, type=(31, 163, 15) (prev=132)
# Skipped 80 bad bytes in log at offset 10919021, type=(167, 149, 138) (prev=133)
# Skipped 78 bad bytes in log at offset 10919140, type=(131, 149, 73) (prev=200)
# Skipped 55 bad bytes in log at offset 10919257, type=(167, 149, 64) (prev=204)
# Skipped 40 bad bytes in log at offset 10919415, type=(167, 149, 68) (prev=67)
# Skipped 35 bad bytes in log at offset 10919537, type=(227, 149, 70) (prev=69)
# Skipped 115 bad bytes in log at offset 10919641, type=(149, 79, 54) (prev=73)
# Skipped 35 bad bytes in log at offset 10919789, type=(162, 149, 84) (prev=83)
# Skipped 67 bad bytes in log at offset 10950667, type=(162, 133, 82) (prev=81)
# Skipped 27 bad bytes in log at offset 10950809, type=(163, 149, 127) (prev=85)
# Skipped 34 bad bytes in log at offset 10950891, type=(171, 149, 87) (prev=86)
# Skipped 27 bad bytes in log at offset 10950993, type=(161, 149, 96) (prev=89)
# Skipped 31 bad bytes in log at offset 10951065, type=(51, 149, 87) (prev=141)
# Skipped 88 bad bytes in log at offset 10951144, type=(163, 157, 1) (prev=0)
# Skipped 21 bad bytes in log at offset 10951271, type=(163, 181, 11) (prev=136)
# Skipped 53 bad bytes in log at offset 10951402, type=(161, 151, 138) (prev=133)
# Skipped 27 bad bytes in log at offset 10951561, type=(163, 181, 166) (prev=138)
# Skipped 129 bad bytes in log at offset 10951705, type=(163, 213, 204) (prev=202)
# Skipped 67 bad bytes in log at offset 10951957, type=(23, 117, 171) (prev=69)
# Skipped 33 bad bytes in log at offset 10952059, type=(179, 149, 71) (prev=70)
# Skipped 82 bad bytes in log at offset 10952385, type=(0, 0, 0) (prev=87)
# Skipped 30 bad bytes in log at offset 10952505, type=(170, 16, 0) (prev=216)
# Skipped 19 bad bytes in log at offset 10952638, type=(179, 149, 237) (prev=199)
# Skipped 49 bad bytes in log at offset 10952686, type=(163, 149, 17) (prev=0)
# Skipped 39 bad bytes in log at offset 10952774, type=(131, 149, 141) (prev=135)
# Skipped 53 bad bytes in log at offset 10953028, type=(131, 149, 138) (prev=133)
# Skipped 102 bad bytes in log at offset 10953162, type=(138, 157, 137) (prev=137)
# Skipped 28 bad bytes in log at offset 10953291, type=(189, 193, 118) (prev=96)
# Skipped 75 bad bytes in log at offset 10953387, type=(131, 149, 195) (prev=66)
# Skipped 33 bad bytes in log at offset 10953579, type=(163, 213, 71) (prev=70)
# Skipped 55 bad bytes in log at offset 10953674, type=(163, 148, 81) (prev=79)
# Skipped 10 bad bytes in log at offset 10953861, type=(107, 58, 30) (prev=213)
# Skipped 33 bad bytes in log at offset 10953987, type=(167, 149, 216) (prev=87)
# Skipped 76 bad bytes in log at offset 10954082, type=(163, 181, 141) (prev=96)
# Skipped 17 bad bytes in log at offset 10954189, type=(2, 95, 210) (prev=196)
# Skipped 21 bad bytes in log at offset 10954333, type=(179, 181, 11) (prev=136)
# Skipped 14 bad bytes in log at offset 10954481, type=(0, 0, 0) (prev=136)
# Skipped 133 bad bytes in log at offset 10954709, type=(227, 149, 138) (prev=133)
# Skipped 19 bad bytes in log at offset 10954889, type=(0, 0, 4) (prev=230)
# Skipped 90 bad bytes in log at offset 10955025, type=(163, 133, 64) (prev=204)
# Skipped 75 bad bytes in log at offset 10955148, type=(163, 151, 66) (prev=66)
# Skipped 90 bad bytes in log at offset 10955250, type=(163, 181, 69) (prev=78)
# Skipped 164 bad bytes in log at offset 10955428, type=(8, 40, 191) (prev=74)
# Skipped 27 bad bytes in log at offset 10955632, type=(163, 133, 95) (prev=85)
# Skipped 33 bad bytes in log at offset 10955748, type=(163, 181, 88) (prev=87)
# Skipped 27 bad bytes in log at offset 10955816, type=(163, 181, 96) (prev=89)
# Skipped 50 bad bytes in log at offset 10955888, type=(162, 181, 103) (prev=141)
# Skipped 39 bad bytes in log at offset 10956055, type=(161, 149, 8) (prev=135)
# Skipped 35 bad bytes in log at offset 10956115, type=(163, 213, 238) (prev=11)
# Skipped 30 bad bytes in log at offset 10956226, type=(185, 188, 42) (prev=154)
# Skipped 72 bad bytes in log at offset 10956290, type=(191, 0, 0) (prev=149)
# Skipped 78 bad bytes in log at offset 10956389, type=(167, 149, 200) (prev=166)
# Skipped 158 bad bytes in log at offset 10956545, type=(39, 149, 64) (prev=204)
# Skipped 27 bad bytes in log at offset 10956743, type=(161, 149, 70) (prev=68)
# Skipped 33 bad bytes in log at offset 10956860, type=(167, 145, 71) (prev=70)
# Skipped 62 bad bytes in log at offset 10956893, type=(163, 149, 106) (prev=70)
# Skipped 8 bad bytes in log at offset 10957002, type=(246, 255, 253) (prev=209)
# Skipped 34 bad bytes in log at offset 10957078, type=(149, 84, 83) (prev=87)
# Skipped 55 bad bytes in log at offset 10957179, type=(166, 149, 86) (prev=95)
# Skipped 32 bad bytes in log at offset 10957304, type=(83, 92, 172) (prev=90)
# Skipped 29 bad bytes in log at offset 10957458, type=(163, 149, 32) (prev=236)
# Skipped 78 bad bytes in log at offset 10957536, type=(163, 133, 135) (prev=1)
# Skipped 35 bad bytes in log at offset 10957635, type=(163, 149, 222) (prev=11)
# Skipped 34 bad bytes in log at offset 10957915, type=(161, 151, 185) (prev=138)
# Skipped 10 bad bytes in log at offset 10957973, type=(0, 0, 132) (prev=190)
# Skipped 78 bad bytes in log at offset 10958103, type=(163, 132, 200) (prev=166)
# Skipped 39 bad bytes in log at offset 10958220, type=(227, 149, 204) (prev=202)
# Skipped 35 bad bytes in log at offset 10958314, type=(171, 149, 65) (prev=64)
# Skipped 34 bad bytes in log at offset 10958724, type=(163, 149, 114) (prev=81)
# Skipped 75 bad bytes in log at offset 10958791, type=(163, 148, 84) (prev=83)
# Skipped 35 bad bytes in log at offset 10960149, type=(163, 213, 72) (prev=71)
# Skipped 55 bad bytes in log at offset 10960435, type=(167, 149, 86) (prev=95)
# Skipped 15 bad bytes in log at offset 10963267, type=(67, 157, 173) (prev=68)
# Skipped 27 bad bytes in log at offset 10963385, type=(131, 149, 79) (prev=72)
# Skipped 35 bad bytes in log at offset 10963534, type=(163, 149, 20) (prev=83)
# Skipped 55 bad bytes in log at offset 10963636, type=(163, 149, 22) (prev=95)
# Skipped 31 bad bytes in log at offset 10963865, type=(163, 151, 199) (prev=141)
# Skipped 29 bad bytes in log at offset 10963915, type=(131, 149, 0) (prev=236)
# Skipped 53 bad bytes in log at offset 10996789, type=(163, 145, 133) (prev=212)
# Skipped 39 bad bytes in log at offset 10996922, type=(35, 149, 200) (prev=166)
# Skipped 90 bad bytes in log at offset 10997078, type=(161, 149, 192) (prev=204)
# Skipped 5 bad bytes in log at offset 10997271, type=(57, 60, 137) (prev=84)
# Skipped 35 bad bytes in log at offset 10997358, type=(163, 213, 70) (prev=69)
# Skipped 89 bad bytes in log at offset 10997488, type=(163, 148, 81) (prev=79)
# Skipped 35 bad bytes in log at offset 10997610, type=(34, 21, 84) (prev=83)
# Skipped 55 bad bytes in log at offset 10997712, type=(161, 149, 86) (prev=95)
# Skipped 1 bad bytes in log at offset 10997800, type=(0, 163, 149) (prev=83)
# Skipped 35 bad bytes in log at offset 10997834, type=(163, 133, 89) (prev=88)
# Skipped 49 bad bytes in log at offset 10998020, type=(171, 149, 1) (prev=0)
# Skipped 25 bad bytes in log at offset 10998122, type=(0, 0, 64) (prev=133)
# Skipped 17 bad bytes in log at offset 10998186, type=(64, 183, 66) (prev=10)
# Skipped 53 bad bytes in log at offset 10998256, type=(163, 148, 138) (prev=133)
# Skipped 53 bad bytes in log at offset 10998342, type=(163, 181, 133) (prev=239)
# Skipped 34 bad bytes in log at offset 10998482, type=(163, 151, 186) (prev=185)
# Skipped 122 bad bytes in log at offset 10998553, type=(149, 139, 148) (prev=167)
# Skipped 39 bad bytes in log at offset 10998753, type=(227, 133, 204) (prev=202)
# Skipped 35 bad bytes in log at offset 10998847, type=(131, 149, 65) (prev=64)
# Skipped 53 bad bytes in log at offset 10998937, type=(130, 70, 58) (prev=74)
# Skipped 185 bad bytes in log at offset 10999017, type=(163, 21, 69) (prev=78)
# Skipped 8 bad bytes in log at offset 10999351, type=(0, 0, 20) (prev=80)
# Skipped 27 bad bytes in log at offset 10999399, type=(163, 157, 95) (prev=85)
# Skipped 35 bad bytes in log at offset 10999548, type=(163, 157, 89) (prev=88)
# Skipped 71 bad bytes in log at offset 10999663, type=(0, 0, 0) (prev=133)
# Skipped 99 bad bytes in log at offset 10999783, type=(163, 148, 134) (prev=1)
# Skipped 8 bad bytes in log at offset 11000090, type=(137, 65, 1) (prev=141)
# Skipped 240 bad bytes in log at offset 11000217, type=(227, 149, 201) (prev=136)
# Skipped 7 bad bytes in log at offset 11000525, type=(46, 153, 61) (prev=76)
# Skipped 47 bad bytes in log at offset 11000567, type=(32, 1, 4) (prev=206)
# Skipped 35 bad bytes in log at offset 11000682, type=(167, 149, 72) (prev=71)
# Skipped 89 bad bytes in log at offset 11000744, type=(163, 133, 81) (prev=79)
# Skipped 75 bad bytes in log at offset 11000866, type=(167, 149, 116) (prev=83)
# Skipped 33 bad bytes in log at offset 11001057, type=(35, 149, 88) (prev=87)
# Skipped 45 bad bytes in log at offset 11001152, type=(35, 149, 141) (prev=96)
# bad msg at offset 11001307 'utf-8' codec can't decode byte 0x98 in position 1: invalid start byte
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# <ipython-input-1-6212a4a09453> in <module>
#      48
#      49
# ---> 50 bin=Flight.from_log('./braking/00000134.BIN')
#      51 flight = rotate_data(bin, -126*pi/180)
#
# ~/source/PyFlightCoach/FlightData/flightdata/data.py in from_log(log_path)
#      54         _field_request = ['ARSP', 'BARO', 'GPS', 'RCIN', 'RCOU', 'IMU',
#      55                         'BAT', 'BAT2', 'MODE', 'NKF1', 'NKF2', 'XKF1', 'XKF2', 'RPM']
# ---> 56         _parser = Ardupilot(log_path, types=_field_request, zero_time_base=True)
#      57         fulldf = _parser.join_logs(_field_request)
#      58
#
# ~/source/PyFlightCoach/ArdupilotLogReader/ardupilot_log_reader/reader.py in __init__(self, bin_file, no_timestamps, planner, robust, condition, types, nottypes, dialect, zero_time_base, source_system, source_component, link, mav10)
#     160             dfs_dicts[m.get_type()]['timestamp'].append( getattr(m,'_timestamp', 0.0) )
#     161             for field in m.get_fieldnames():
# --> 162                 dfs_dicts[m.get_type()][field].append( getattr(m,field) )
#     163
#     164         self._dfs = {}
#
# ~/miniconda3/envs/pyflightcoach/lib/python3.8/site-packages/pymavlink/DFReader.py in __getattr__(self, field)
#     182             raise AttributeError(field)
#     183         if isinstance(self._elements[i], bytes):
# --> 184             v = self._elements[i].decode("utf-8")
#     185         else:
#     186             v = self._elements[i]
#
# UnicodeDecodeError: 'utf-8' codec can't decode byte 0x98 in position 1: invalid start byte

# %% [markdown]
# A flight was performed consisting of many vertical lines with different throttle settings. The figure below shows a position trace of the flight.

# %%
plot3d(*flight.read_field_tuples(Fields.POSITION)).show()

# %% [markdown]
# Below the relevant data for analysis is extracted from the log:

# %%
from math import sqrt

M = 4.4

rpm_data = flight.read_fields([Fields.RPM, Fields.TXCONTROLS, Fields.POSITION, Fields.VELOCITY])
rpm_data = rpm_data[['rpm_0', 'tx_controls_0'] + Fields.POSITION.names + Fields.VELOCITY.names]
rpm_data['rpm_0'] = rpm_data['rpm_0'] / 280
rpm_data.columns = 'rpm,throttle,x,y,z,vx,vy,vz'.split(',')

rpm_data['v'] = np.vectorize(lambda x,y,z: sqrt(x**2 + y**2 + z**2))(rpm_data.vx, rpm_data.vy, rpm_data.vz)
diffs = rpm_data.v.diff()
steps = pd.Series(rpm_data.index).diff()
v = np.vectorize(lambda n, d: n / d)(diffs, steps)
rpm_data['a'] = v

rpm_data['body_x_force'] = M * rpm_data.a

rpm_data.sample(10)

# %% [markdown]
# Initial tests were performed on the ground, to see RPM response to step changes input:

# %%
import plotly.graph_objects as go
from plotly.subplots import make_subplots

static_rpmdata = rpm_data.loc[111: 120]


fig = make_subplots(specs=[[{"secondary_y": True}]])
fig.add_trace(go.Scatter(x=static_rpmdata.index, y=static_rpmdata.throttle, name='throttle'),secondary_y=False)
fig.add_trace(go.Scatter(x=static_rpmdata.index, y=static_rpmdata.rpm, name='rpm'),secondary_y=True)
fig.update_xaxes(title_text="time")
fig.update_yaxes(title_text="throttle", secondary_y=False)
fig.update_yaxes(title_text="rpm", secondary_y=True)
fig.show()


fig=go.Figure()
fig.add_trace(go.Scatter(x=static_rpmdata.throttle, y=static_rpmdata.rpm, mode='markers'))
fig.update_layout(width = 800, height = 500, margin=dict(l=20, r=20, t=20, b=20),)
fig.update_xaxes(title_text="throttle")
fig.update_yaxes(title_text="rpm")

fig.show()

# %% [markdown]
# Next split the flight into individual up and downlines:

# %%
lines = [
    [196, 208], [213,216], [223,228], [234,239], [244,252], [258,263], [268,278], [284,290], [294,309], [314,320], [326,336], [342,347],
    [352,364],[370,376],[381,391],[396,403],[408,419],[423,429],[434,444],[450,455],[460,470],[475,480],[485,495],[500,505],[510,519],[524,529],[534,542],
    [548,552],[558,566],[572,577]
]

class Line():
    def __init__(self, data):
        self.data = data
        self.throttle = data.throttle.mean()
        self.rpm = data.rpm.mean()
        self.func = None
        if self.rpm < 60:
            self.rpm = 0

    def isupline(self):
        return self.data.iloc[-1].z > self.data.iloc[0].z

    def get_prop_drag(self, u):
        return self.func[0] * u**3 + self.func[1] * u**2 + self.func[2] * u + self.func[3]


uplines = []
upline_refs = []
downlines = []
downline_refs = []
for line in lines:
    lin = Line(rpm_data.loc[line[0]:line[1]])
    if lin.isupline():
        uplines.append(lin)
        upline_refs.append([len(uplines) -1, lin.throttle, lin.rpm])
    else:
        downlines.append(lin)
        downline_refs.append([len(uplines)-1, lin.throttle, lin.rpm])

downline_refs = pd.DataFrame(downline_refs, columns='id,throttle,rpm'.split(',')).sort_values('rpm')
upline_refs = pd.DataFrame(upline_refs, columns='id,throttle,rpm'.split(','))

downline_refs

# %% [markdown]
# Two tests were performed with the prop stopped, these can be used to calculate Cd0:

# %%
rho = 1.225
S = 0.15*2 # Guessed wing area, need to measure it

def get_downline_cd0(u, f):
    return (M * 9.81 - f) / (0.5 * rho * u**2 * S)

prop_stopped_tests = downline_refs.loc[downline_refs.rpm == 0]


fig=go.Figure()

temp = []
for id in prop_stopped_tests.id.to_list():
    test = downlines[id]
    test.data['cd0'] = np.vectorize(get_downline_cd0)(test.data.v, test.data.body_x_force) 
    
    temp.append(test.data['cd0'].mean())
    print('cd0 from test ', id, ' = ', test.data['cd0'].mean())
    print('standard deviation in cd0 from test ', id, ' = ', test.data['cd0'].std())

    fig.add_trace(go.Scatter(x=test.data.v, y=test.data.cd0))

Cd0 = sum(temp) / len(prop_stopped_tests.id.to_list())

fig.update_layout(width = 800, height = 500, margin=dict(l=20, r=20, t=20, b=20),)
fig.update_xaxes(title_text="u (m/s)")
fig.update_yaxes(title_text="Cd0")

fig.show()

# %% [markdown]
# Now that Cd0 has been estimated the additional contribution to drag from the prop turning can be calculated for the other tests

# %%
def get_drag_force(u):
    return 0.5 * rho * u**2 * S * Cd0

def get_downline_prop_drag(u, f):
    return 9.81 * M - f - get_drag_force(u)


fig = go.Figure()
meandata = []
for id in downline_refs.id.to_list():
    test = downlines[id]
    test.data['prop_drag'] = np.vectorize(get_downline_prop_drag)(test.data.v, test.data.body_x_force)

    test.func = np.polyfit(test.data.v, test.data.prop_drag,3)

    test.data['simple_prop_drag'] = np.vectorize(test.get_prop_drag)(test.data.v)

    fig.add_trace(go.Scatter(x=test.data.v, y=test.data.simple_prop_drag, name=int(test.rpm)))
fig.update_layout(title= 'Propeller Braking Force vs Airpseed for a Range of RPMs')
fig.update_xaxes(title_text="airspeed (m/s)")
fig.update_yaxes(title_text="prop braking force (N)")
fig.update_layout(yaxis_range=[-5, 10], xaxis_range=[33, 40])
fig.update_layout(width = 800, height = 600, margin=dict(l=20, r=20, t=40, b=20),)
fig.show()

# %%
print('Cd0 = ', str("{:.2f}".format(no_power.Cd0.mean())))
